# %%
import pandas as pd

# %%
df = pd.read_csv("spotify_millsongdata.csv")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df =df.sample(10000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#             artist                            song  \
# 0  George Harrison                             You
# 1          Outkast                           Intro
# 2             Korn                   Slept So Long
# 3            Selah      Wonderful, Merciful Savior
# 4           Bosson                        Rockstar
# 5      Cat Stevens                           Jzero
# 6        Metallica                      One (Rare)
# 7    Queen Latifah                     Turn You On
# 8            Kinks                         Holiday
# 9           Travis  The Last Laugh Of The Laughter
#
#                                                 text
# 0  You  \r\nGeorge Harrison  \r\n  \r\n(one, two,...
# 1  O-U-T-K-A-S-T  \r\nLive, from the center of th...
# 2  Walking, waiting  \r\nAlone without a care  \r...
# 3  Verse 1  \r\nWonderful, merciful Savior  \r\nP...
# 4  He's a kid, with a dream  \r\nBut he's differe...
# 5  Well I ain't got nothing,  \r\nBut it don't wo...
# 6  The cerebrum has suffered massive and reparabl...
# 7  Did I make you hot? Tell me  \r\n  \r\nI didn'...
# 8  Holiday,  \r\nOh what a lovely day today,  \r\...
# 9  When the laughter fade away  \r\nMa vie  \r\nT...

# %%
df['text'][0]
# Out:
# "You  \r\nGeorge Harrison  \r\n  \r\n(one, two,  \r\nOne, two, three, four)  \r\n  \r\nI, I love, love  \r\nAnd I, and I love you  \r\nOh you, you, yeah you  \r\n  \r\nAnd you, you, love, love  \r\nAnd you, yes you, you love me  \r\nYeah you, you, yeah you  \r\n  \r\nAnd when I'm holding you  \r\nWhat a feeling  \r\nSeems so good to be true  \r\nThat I'm telling you all  \r\nThat I must be dreaming  \r\n  \r\nAnd I, and I, I love you  \r\nOh you, oh you, yeah you  \r\n  \r\nAnd when I'm holding you  \r\nWhat a feeling  \r\nSeems so good to be true  \r\nThat I'm telling you all  \r\nThat I must be dreaming  \r\n  \r\nNow I, oh I, I love, love  \r\nAnd I, yeah I, I love you, I love you  \r\nOh you, you, oh you  \r\n  \r\nOh, you know that I love you, oh oh oh  \r\nOh, you know that I love you, I love you, I, I said I love you\r\n\r\n"

# %%
df.shape
# Out:
# (10000, 3)

# %% [markdown]
# Text Cleaning/ Text Preprocessing

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')

from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/user/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['text'] = df['text'].apply(lambda x: tokenization(x))

# %%
	
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'])
similarity = cosine_similarity(matrix)

# %%
similarity[0]

# %%
df[df['song'] == 'Obvious']

# %%
def recommendation(song_df):
    idx = df[df['song'] == song_df].index[0]
    distances = sorted(list(enumerate(similarity[idx])),reverse=True,key=lambda x:x[1])
    
    songs = []
    for m_id in distances[1:21]:
        songs.append(df.iloc[m_id[0]].song)
        
    return songs

# %%
recommendation('Obvious')

# %%
import pickle
pickle.dump(similarity,open('similarity.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))
